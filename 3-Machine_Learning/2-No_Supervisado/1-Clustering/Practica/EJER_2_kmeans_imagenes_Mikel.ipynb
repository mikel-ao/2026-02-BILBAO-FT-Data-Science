# %% [markdown]
# # Agrupando colores

# %% [markdown]
# Vamos a crear imagenes con una cantidad fija de colores

# %% [markdown]
# #### 1. Importa las librerias
# Vamos a necesitar `KMeans` de `sklearn.cluster`, `imread` de `matplotlib.image`, `matplotlib.pyplot` y `numpy`

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %% [markdown]
# #### 2. Lee una imagen
# Utiliza alguna foto que tengas en tu ordenador y leela con la función `imread`
#
# Consejo: utiliza una imagen pequeña si no quieres tardar una eternidad en que se ejecute el kmeans

# %%
image = plt.imread('data/ejer_kmeans.png')
image.shape
# Out:
# (764, 1499, 3)

# %% [markdown]
# Muestra la imagen para ver que se ha cargado bien

# %%
plt.imshow(image)
plt.axis('off') # Opcional, para quitar los ejes
plt.show()

# %% [markdown]
# #### 3. Modifica la estructura de la imagen
# Queremos que cada pixel sea una observación por lo que tenemos que transformar nuestra imagen de un vector de forma (alto, ancho, color) a (alto x ancho, color). Color será siempre 3, que son los tres canales de los colores.
#
# Ej: (300, 400, 3) -> (120000, 3)

# %%
# Guardamos las dimensiones originales para el paso 6
alto, ancho, canales = image.shape

# Cambiamos la forma a (alto * ancho, canales)
data_pixels = image.reshape(alto * ancho, canales)
print(f"Forma dataset: {data_pixels.shape}")
# Out:
# Forma dataset: (1145236, 3)

# %% [markdown]
# #### 4. K-means
# Haz un k-means con la imagen de entrada (Con la nueva forma que le hemos dado). K será el número de colores que quieras que tenga tu imagen de salida

# %%
# Definimos el número de colores (clusters)
n_colores = 8

kmeans = KMeans(n_clusters=n_colores, random_state=42, n_init='auto')
kmeans.fit(data_pixels)
# Out:
# KMeans(random_state=42)

# %% [markdown]
# #### 5. Sustituye cada valor por su centroide
#
# Una vez hemos entrenado el kmeans entre otros parametros de salida tiene `cluster_centers_` y `labels_`. Utilizlos para crear una nueva imagen (recuerda que las imagenes simplemente son vectores numéricos) en la que cada pixel se sustituye por su centroide correspondiente.

# %%
# Obtenemos los colores (centroides) y las etiquetas de cada píxel
colores_centroides = kmeans.cluster_centers_
etiquetas = kmeans.labels_

# Creamos el nuevo array de píxeles usando los centroides
# Cada etiqueta funciona como índice para el color del centroide
new_pixels = colores_centroides[etiquetas]

# %% [markdown]
# #### 6. Modifica la estructura de la imagen
# Para trabajar con el k-means requeriamos que la imagen original fuese un solo vector, ahora como queremos volver a tener la imagen para volver mostrarla debemos hacer el proceso inverso a el paso 3. (Si has guardado la forma de la imagen original te será más facil hacer este paso)

# %%
# Usamos las dimensiones que guardamos en el paso 3
new_image = new_pixels.reshape(alto, ancho, canales)

# %% [markdown]
# #### 7. Muestra y guarda en tu ordenador la imagen resultante

# %%
# Mostrar resultado
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.title("Original")
plt.imshow(image)

plt.subplot(1, 2, 2)
plt.title(f"K-Means ({n_colores} colores)")
plt.imshow(new_image)
plt.show()

# Guardar en el ordenador
plt.imsave('imagen_comprimida.png', new_image)

# %% [markdown]
# #### 8. Crea una función
# Crea una función que tenga como argumentos de entrada una imagen, el numero de colores que quieres que tenga, y si se quiere guardar o mostrar por pantalla

# %%
def procesar_imagen_kmeans(ruta_imagen, n_clusters, guardar=False, mostrar=True):
    # Leer
    img = plt.imread(ruta_imagen)
    h, w, c = img.shape
    
    # Reshape para K-means
    pixels = img.reshape(-1, c) # -1 calcula automáticamente h*w
    
    # Modelo
    model = KMeans(n_clusters=n_clusters, random_state=42, n_init='auto')
    labels = model.fit_predict(pixels)
    centers = model.cluster_centers_
    
    # Reconstruir
    new_img = centers[labels].reshape(h, w, c)
    
    if mostrar:
        plt.imshow(new_img)
        plt.title(f"Imagen con {n_clusters} colores")
        plt.axis('off')
        plt.show()
        
    if guardar:
        nombre_archivo = f"resultado_{n_clusters}_colores.png"
        plt.imsave(nombre_archivo, new_img)
        print(f"Imagen guardada como {nombre_archivo}")
        
    return new_img

# Ejemplo de uso:
procesar_imagen_kmeans('data/ejer_kmeans.png', 256, guardar=True)
# Out:
# Imagen guardada como resultado_256_colores.png
# array([[[0.57298696, 0.59789306, 0.6173572 ],
#         [0.5389234 , 0.56111526, 0.5738601 ],
#         [0.5389234 , 0.56111526, 0.5738601 ],
#         ...,
#         [0.7599393 , 0.7843377 , 0.78966826],
#         [0.7599393 , 0.7843377 , 0.78966826],
#         [0.12774602, 0.13455996, 0.14451525]],
#
#        [[0.57298696, 0.59789306, 0.6173572 ],
#         [0.5389234 , 0.56111526, 0.5738601 ],
#         [0.5389234 , 0.56111526, 0.5738601 ],
#         ...,
#         [0.78086174, 0.8080071 , 0.80845195],
#         [0.7599393 , 0.7843377 , 0.78966826],
#         [0.12774602, 0.13455996, 0.14451525]],
#
#        [[0.57298696, 0.59789306, 0.6173572 ],
#         [0.5389234 , 0.56111526, 0.5738601 ],
#         [0.5389234 , 0.56111526, 0.5738601 ],
#         ...,
#         [0.78086174, 0.8080071 , 0.80845195],
#         [0.78086174, 0.8080071 , 0.80845195],
#         [0.12774602, 0.13455996, 0.14451525]],
#
#        ...,
#
#        [[0.25529715, 0.2789103 , 0.30567586],
#         [0.25529715, 0.2789103 , 0.30567586],
#         [0.25529715, 0.2789103 , 0.30567586],
#         ...,
#         [0.9993501 , 0.99933714, 0.99931407],
#         [0.9993501 , 0.99933714, 0.99931407],
#         [0.12774602, 0.13455996, 0.14451525]],
#
#        [[0.25529715, 0.2789103 , 0.30567586],
#         [0.25529715, 0.2789103 , 0.30567586],
#         [0.25529715, 0.2789103 , 0.30567586],
#         ...,
#         [0.9372472 , 0.94237053, 0.90214026],
#         [0.91761476, 0.9278587 , 0.88995373],
#         [0.12774602, 0.13455996, 0.14451525]],
#
#        [[0.12774602, 0.13455996, 0.14451525],
#         [0.12774602, 0.13455996, 0.14451525],
#         [0.12774602, 0.13455996, 0.14451525],
#         ...,
#         [0.12774602, 0.13455996, 0.14451525],
#         [0.12774602, 0.13455996, 0.14451525],
#         [0.12774602, 0.13455996, 0.14451525]]], dtype=float32)
